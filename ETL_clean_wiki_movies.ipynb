# %%
import json
import pandas as pd
import numpy as np

import re

from sqlalchemy import create_engine
import psycopg2

# from config import db_password

import time

import warnings
warnings.filterwarnings("ignore")

# %%
# 1. Add the clean movie function that takes in the argument, "movie".
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    return movie

# %%
# 2 Add the function that takes in three arguments;
# Wikipedia data, Kaggle metadata, and MovieLens rating data (from Kaggle)

def extract_transform_load(wiki_file, kaggle_file, ratings_file):    
    
    file_dir = 'C://Users/KenAk/ETL/Movies-ETL/'
    
    # Read in the kaggle metadata and MovieLens ratings CSV files as Pandas DataFrames.

    kaggle_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
    ratings = pd.read_csv(f'{file_dir}ratings.csv')
    
    # Open and read the Wikipedia data JSON file.
 
    with open(f'{file_dir}/wikipedia-movies.json', mode='r') as file:
        wiki_movies_raw = json.load(file)
    
    # 3. Write a list comprehension to filter out TV shows. Code from near bottom of 8.3.3
    # The TV shows are filtered out, and the wiki_movies_df DataFrame is created (3 pt)
    
    wiki_movies = [movie for movie in wiki_movies_raw
                   if ('Director' in movie or 'Directed by' in movie)
                       and 'imdb_link' in movie
                       and 'No. of episodes' not in movie]
    
    # 4. Write a list comprehension to iterate through the cleaned wiki movies list and call the clean_movie function on each movie.
    # We can make a list of cleaned movies with a list comprehension
    
    clean_movies = [clean_movie(movie) for movie in wiki_movies]

    # 5. Read in the cleaned movies list from Step 4 as a DataFrame.

    wiki_movies_df = pd.DataFrame(clean_movies)
    
    # 6. Write a try-except block to catch errors while extracting the IMDb ID using a regular expression string and
    #  dropping any imdb_id duplicates. If there is an error, capture and print the exception.
    # A try-except block is used to catch errors while extracting the IMDb IDs with a regular expression and dropping duplicate IDs. (5 pt)
    try:
        wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')
        print("Number of movies before dropping duplicates:", len(wiki_movies_df))
        wiki_movies_df.drop_duplicates(subset='imdb_id', inplace=True)
        print("Number of movies after dropping duplicates: ",len(wiki_movies_df))
    except:
        print("An exception occurred")

    #  7. Write a list comprehension to keep the columns that don't have null values from the wiki_movies_df DataFrame.
    # That will give us the columns that we want to keep, which we can select from our Pandas DataFrame
    # A list comprehension is used to keep columns with non-null values (3 pt)
    wiki_columns_to_keep = [column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]
    wiki_movies_df = wiki_movies_df[wiki_columns_to_keep]
     
    # 8. Create a variable that will hold the non-null values from the “Box office” column.
    # The non-null box office data is converted to string values using the lambda and join functions (3 pt)

    Box_Office = wiki_movies_df['Box office'].dropna() #drop missing values
    
    # 9. Convert the box office data created in Step 8 to string values using the lambda and join functions.  
    # Lambda functions don't have a name and automatically return a variable
    Box_Office[Box_Office.map(lambda x: type(x) != str)]
    # Instead of creating a new function with a block of code and the def keyword, we can create an anonymous lambda function right inside the map() call

    # 10. Write a regular expression to match the six elements of "form_one" of the box office data.  
    # 8.3.10 Parse the Box Office Data; A regular expression is used to match the six elements of "form_one" of the box office data (2 pt)
    form_one = r'\$\d+\.?\d*\s*[mb]illi?on'
    Box_Office.str.contains(form_one, flags=re.IGNORECASE, na=False).sum()
    
    # 11. Write a regular expression to match the three elements of "form_two" of the box office data.
    # A regular expression is used to match the three elements of "form_two" of the box office data (2 pt)
    form_two = r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illi?on)'
    Box_Office.str.contains(form_two, flags=re.IGNORECASE, na=False).sum()
    
    # 12. Add the parse_dollars function.
    def parse_dollars(s):
        # if s is not a string, return NaN
        if type(s) != str:
            return np.nan

        # if input is of the form $###.# million
        if re.match(r'\$\s*\d+\.?\d*\s*milli?on', s, flags=re.IGNORECASE):

            # remove dollar sign and " million"
            s = re.sub('\$|\s|[a-zA-Z]','', s)

            # convert to float and multiply by a million
            value = float(s) * 10**6

            # return value
            return value

        # if input is of the form $###.# billion
        elif re.match(r'\$\s*\d+\.?\d*\s*billi?on', s, flags=re.IGNORECASE):

            # remove dollar sign and " billion"
            s = re.sub('\$|\s|[a-zA-Z]','', s)

            # convert to float and multiply by a billion
            value = float(s) * 10**9

            # return value
            return value

        # if input is of the form $###,###,###
        elif re.match(r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illi?on)', s, flags=re.IGNORECASE):

            # remove dollar sign and commas
            s = re.sub('\$|,','', s)

            # convert to float
            value = float(s)

            # return value
            return value

        # otherwise, return NaN
        else:
            return np.nan
    
    # The following columns are cleaned in the Wikipedia DataFrame: (8 pt)
    
    # The box office column
    # The budget column
    # The release date column
    # The running time column
    
    # 13. Clean the box office column in the wiki_movies_df DataFrame.

    wiki_movies_df['Box_Office'] = Box_Office.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)
    wiki_movies_df.drop('Box office', axis=1, inplace=True)
    
    # 14. Clean the budget column in the wiki_movies_df DataFrame.
    
    budget = wiki_movies_df['Budget'].dropna()
    budget = budget.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)
    matches_form_one = budget.str.contains(form_one, flags=re.IGNORECASE, na=False)
    matches_form_two = budget.str.contains(form_two, flags=re.IGNORECASE, na=False)
    budget[~matches_form_one & ~matches_form_two]
    # Remove the citation references with the following:
    budget = budget.str.replace(r'\[\d+\]\s*', '')
    budget[~matches_form_one & ~matches_form_two]
    # make a variable that holds the non-null values of Release date in the DataFrame, converting lists to strings
    wiki_movies_df['budget'] = budget.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)
    # We can also drop the original Budget column
    wiki_movies_df.drop('Budget', axis=1, inplace=True)
    
    # 15. Clean the release date column in the wiki_movies_df DataFrame.
    
    # make a variable that holds the non-null values of Release date in the DataFrame, converting lists to strings

    Release_Date = wiki_movies_df['Release date'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)
    
    # The forms we'll be parsing are:

    # 1. Full month name, one- to two-digit day, four-digit year (i.e., January 1, 2000)
    # 2. Four-digit year, two-digit month, two-digit day, with any separator (i.e., 2000-01-01)
    # 3. Full month name, four-digit year (i.e., January 2000)
    # 4. Four-digit year

    date_form_one = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s[123]?\d,\s\d{4}'
    date_form_two = r'\d{4}.[01]\d.[0123]\d'
    date_form_three = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}'
    date_form_four = r'\d{4}'
    
    # Extract the dates

    Release_Date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})', flags=re.IGNORECASE)
    wiki_movies_df['Release_Date'] = pd.to_datetime(Release_Date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})')[0], infer_datetime_format=True)
    # We can also drop the original Release date column
    wiki_movies_df.drop('Release date', axis=1, inplace=True)
    
    # 16. Clean the running time column in the wiki_movies_df DataFrame.
    # Parse running time
    Running_Time = wiki_movies_df['Running time'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)
    running_time_extract = Running_Time.str.extract(r'(\d+)\s*ho?u?r?s?\s*(\d*)|(\d+)\s*m')
    running_time_extract = running_time_extract.apply(lambda col: pd.to_numeric(col, errors='coerce')).fillna(0)
    wiki_movies_df['Running_Time'] = running_time_extract.apply(lambda row: row[0]*60 + row[1] if row[2] == 0 else row[2], axis=1)
    wiki_movies_df.drop('Running time', axis=1, inplace=True)
    
    # Return three variables. The first is the wiki_movies_df DataFrame  
    return wiki_movies_df, kaggle_metadata, ratings

# %%
# 17. Create the path to your file directory and variables for the three files.
file_dir = 'C://Users/KenAk/ETL/Movies-ETL/'
# The Wikipedia data
wiki_file = f'{file_dir}/wikipedia_movies.json'
# The Kaggle metadata
kaggle_file = f'{file_dir}/movies_metadata.csv'
# The MovieLens rating data.
ratings_file = f'{file_dir}/ratings.csv'

# %%
ratings_file
# Out:
# 'C://Users/KenAk/ETL/Movies-ETL//ratings.csv'

# %%
# 18. Set the three variables equal to the function created in D1.
wiki_file, kaggle_file, ratings_file = extract_transform_load(wiki_file, kaggle_file, ratings_file)
# Out:
# Number of movies before dropping duplicates: 7076
# Number of movies after dropping duplicates:  7033

# %%
wiki_file
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 7071    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018
# 7072     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018
# 7073  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018
# 7074  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018
# 7075  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1     https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2     https://www.imdb.com/title/tt0099005/                      Air America
# 3     https://www.imdb.com/title/tt0099012/                            Alice
# 4     https://www.imdb.com/title/tt0099018/                  Almost an Angel
# ...                                     ...                              ...
# 7071  https://www.imdb.com/title/tt1255919/                  Holmes & Watson
# 7072  https://www.imdb.com/title/tt6266538/                             Vice
# 7073  https://www.imdb.com/title/tt4669788/              On the Basis of Sex
# 7074  https://www.imdb.com/title/tt7137380/                        Destroyer
# 7075  https://www.imdb.com/title/tt9495224/                     Bandersnatch
#
#              Directed by                                        Produced by  \
# 0           Renny Harlin                         [Steve Perry, Joel Silver]
# 1            James Foley                        [Ric Kidney, Robert Redlin]
# 2     Roger Spottiswoode                                     Daniel Melnick
# 3            Woody Allen                                    Robert Greenhut
# 4           John Cornell                                       John Cornell
# ...                  ...                                                ...
# 7071          Etan Cohen  [Will Ferrell, Adam McKay, Jimmy Miller, Clayt...
# 7072          Adam McKay  [Brad Pitt, Dede Gardner, Jeremy Kleiner, Kevi...
# 7073          Mimi Leder                                     Robert W. Cort
# 7074        Karyn Kusama             [Fred Berger, Phil Hay, Matt Manfredi]
# 7075         David Slade                                     Russell McLean
#
#                                    Screenplay by                     Story by  \
# 0     [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                   [James Foley, Robert Redlin]                          NaN
# 2                     [John Eskow, Richard Rush]                          NaN
# 3                                            NaN                          NaN
# 4                                            NaN                          NaN
# ...                                          ...                          ...
# 7071                                  Etan Cohen                          NaN
# 7072                                         NaN                          NaN
# 7073                                         NaN                          NaN
# 7074                                         NaN                          NaN
# 7075                                         NaN                          NaN
#
#                                                Based on  \
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7071  [Sherlock Holmes, and, Dr. Watson, by, Sir Art...
# 7072                                                NaN
# 7073                                                NaN
# 7074                                                NaN
# 7075                                                NaN
#
#                                                Starring  ...  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...  ...
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...
# ...                                                 ...  ...
# 7071  [Will Ferrell, John C. Reilly, Rebecca Hall, R...  ...
# 7072  [Christian Bale, Amy Adams, Steve Carell, Sam ...  ...
# 7073  [Felicity Jones, Armie Hammer, Justin Theroux,...  ...
# 7074  [Nicole Kidman, Sebastian Stan, Toby Kebbell, ...  ...
# 7075  [Fionn Whitehead, Will Poulter, Craig Parkinso...  ...
#
#                Distributed by         Country        Language  \
# 0            20th Century Fox   United States         English
# 1             Avenue Pictures   United States         English
# 2            TriStar Pictures   United States  [English, Lao]
# 3              Orion Pictures   United States         English
# 4          Paramount Pictures              US         English
# ...                       ...             ...             ...
# 7071  Sony Pictures Releasing   United States         English
# 7072         Mirror Releasing   United States         English
# 7073           Focus Features   United States         English
# 7074         Mirror Releasing   United States         English
# 7075                  Netflix  United Kingdom         English
#
#                      Written by  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                   Woody Allen
# 4                    Paul Hogan
# ...                         ...
# 7071                        NaN
# 7072                 Adam McKay
# 7073          Daniel Stiepleman
# 7074  [Phil Hay, Matt Manfredi]
# 7075            Charlie Brooker
#
#                                    Productioncompanies     imdb_id  \
# 0                                                   NaN  tt0098987
# 1                                                   NaN  tt0098994
# 2                                                   NaN  tt0099005
# 3                                                   NaN  tt0099012
# 4                                                   NaN  tt0099018
# ...                                                 ...        ...
# 7071  [Columbia Pictures, Gary Sanchez Productions, ...  tt1255919
# 7072                                                NaN  tt6266538
# 7073  [Focus Features, [1], Participant Media, [1], ...  tt4669788
# 7074                                                NaN  tt7137380
# 7075                                                NaN  tt9495224
#
#       Box_Office      budget Release_Date Running_Time
# 0     21400000.0  20000000.0   1990-07-11        102.0
# 1      2700000.0   6000000.0   1990-05-17        114.0
# 2     57718089.0  35000000.0   1990-08-10        113.0
# 3      7331647.0  12000000.0   1990-12-25        106.0
# 4      6939946.0  25000000.0   1990-12-19         95.0
# ...          ...         ...          ...          ...
# 7071  41900000.0  42000000.0   2018-12-25         90.0
# 7072  76100000.0  60000000.0   2018-12-11        132.0
# 7073  38400000.0  20000000.0   2018-11-08        120.0
# 7074   5500000.0   9000000.0   2018-08-31        123.0
# 7075         NaN         NaN   2018-12-01         90.0
#
# [7033 rows x 24 columns]

# %%
# 19. Set the wiki_movies_df equal to the wiki_file variable. 
wiki_movies_df = wiki_file

# %%
# 20. The cleaned Wikipedia data is converted to a Pandas DataFrame, 
# and the DataFrame is displayed in the ETL_clean_wiki_movies.ipynb file (4 pt)
wiki_movies_df.head(50)
# Out:
#                                                   url  year  \
# 0   https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1   https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2    https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3     https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4       https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# 5         https://en.wikipedia.org/wiki/The_Ambulance  1990
# 6   https://en.wikipedia.org/wiki/American_Dream_(...  1990
# 7   https://en.wikipedia.org/wiki/American_Ninja_4...  1990
# 8      https://en.wikipedia.org/wiki/Andre%27s_Mother  1990
# 9     https://en.wikipedia.org/wiki/Angel_Town_(film)  1990
# 10      https://en.wikipedia.org/wiki/Another_48_Hrs.  1990
# 11  https://en.wikipedia.org/wiki/Arachnophobia_(f...  1990
# 12   https://en.wikipedia.org/wiki/Avalon_(1990_film)  1990
# 13           https://en.wikipedia.org/wiki/Awakenings  1990
# 14  https://en.wikipedia.org/wiki/Back_to_the_Futu...  1990
# 15  https://en.wikipedia.org/wiki/Bad_Influence_(f...  1990
# 16        https://en.wikipedia.org/wiki/Basket_Case_2  1990
# 17    https://en.wikipedia.org/wiki/Betsy%27s_Wedding  1990
# 18  https://en.wikipedia.org/wiki/Bird_on_a_Wire_(...  1990
# 19  https://en.wikipedia.org/wiki/Blind_Faith_(199...  1990
# 20         https://en.wikipedia.org/wiki/Bloodfist_II  1990
# 21  https://en.wikipedia.org/wiki/Blue_Steel_(1990...  1990
# 22  https://en.wikipedia.org/wiki/The_Bonfire_of_t...  1990
# 23  https://en.wikipedia.org/wiki/Bride_of_Re-Anim...  1990
# 24       https://en.wikipedia.org/wiki/Cadence_(film)  1990
# 25         https://en.wikipedia.org/wiki/Cadillac_Man  1990
# 26       https://en.wikipedia.org/wiki/Camp_Cucamonga  1990
# 27  https://en.wikipedia.org/wiki/Captain_America_...  1990
# 28  https://en.wikipedia.org/wiki/Cartoon_All-Star...  1990
# 29            https://en.wikipedia.org/wiki/Catchfire  1990
# 30  https://en.wikipedia.org/wiki/Challenger_(1990...  1990
# 31  https://en.wikipedia.org/wiki/Checkered_Flag_(...  1990
# 32   https://en.wikipedia.org/wiki/Child_in_the_Night  1990
# 33     https://en.wikipedia.org/wiki/Child%27s_Play_2  1990
# 34            https://en.wikipedia.org/wiki/China_Cry  1990
# 35  https://en.wikipedia.org/wiki/The_China_Lake_M...  1990
# 36      https://en.wikipedia.org/wiki/China_O%27Brien  1990
# 37        https://en.wikipedia.org/wiki/Class_of_1999  1990
# 38  https://en.wikipedia.org/wiki/Coins_in_the_Fou...  1990
# 39  https://en.wikipedia.org/wiki/Come_See_the_Par...  1990
# 40  https://en.wikipedia.org/wiki/Coupe_de_Ville_(...  1990
# 41  https://en.wikipedia.org/wiki/Crash_and_Burn_(...  1990
# 42         https://en.wikipedia.org/wiki/Crazy_People  1990
# 43             https://en.wikipedia.org/wiki/Cry-Baby  1990
# 44  https://en.wikipedia.org/wiki/Daddy%27s_Dyin%2...  1990
# 45   https://en.wikipedia.org/wiki/Dances_with_Wolves  1990
# 46  https://en.wikipedia.org/wiki/The_Dark_Side_of...  1990
# 47              https://en.wikipedia.org/wiki/Darkman  1990
# 48  https://en.wikipedia.org/wiki/Daughter_of_Dark...  1990
# 49      https://en.wikipedia.org/wiki/Days_of_Thunder  1990
#
#                                 imdb_link  \
# 0   https://www.imdb.com/title/tt0098987/
# 1   https://www.imdb.com/title/tt0098994/
# 2   https://www.imdb.com/title/tt0099005/
# 3   https://www.imdb.com/title/tt0099012/
# 4   https://www.imdb.com/title/tt0099018/
# 5   https://www.imdb.com/title/tt0099026/
# 6   https://www.imdb.com/title/tt0099028/
# 7   https://www.imdb.com/title/tt0101326/
# 8   https://www.imdb.com/title/tt0099037/
# 9   https://www.imdb.com/title/tt0099039/
# 10  https://www.imdb.com/title/tt0099044/
# 11  https://www.imdb.com/title/tt0099052/
# 12  https://www.imdb.com/title/tt0099073/
# 13  https://www.imdb.com/title/tt0099077/
# 14  https://www.imdb.com/title/tt0099088/
# 15  https://www.imdb.com/title/tt0099091/
# 16  https://www.imdb.com/title/tt0099108/
# 17  https://www.imdb.com/title/tt0099128/
# 18  https://www.imdb.com/title/tt0099141/
# 19  https://www.imdb.com/title/tt0099148/
# 20  https://www.imdb.com/title/tt0099155/
# 21  https://www.imdb.com/title/tt0099160/
# 22  https://www.imdb.com/title/tt0099165/
# 23  https://www.imdb.com/title/tt0099180/
# 24  https://www.imdb.com/title/tt0101531/
# 25  https://www.imdb.com/title/tt0099204/
# 26  https://www.imdb.com/title/tt0099212/
# 27  https://www.imdb.com/title/tt0103923/
# 28  https://www.imdb.com/title/tt0154129/
# 29  https://www.imdb.com/title/tt0096875/
# 30  https://www.imdb.com/title/tt0099237/
# 31  https://www.imdb.com/title/tt0099245/
# 32  https://www.imdb.com/title/tt0099252/
# 33  https://www.imdb.com/title/tt0099253/
# 34  https://www.imdb.com/title/tt0101578/
# 35  https://www.imdb.com/title/tt0099259/
# 36  https://www.imdb.com/title/tt0099260/
# 37  https://www.imdb.com/title/tt0099277/
# 38  https://www.imdb.com/title/tt0099284/
# 39  https://www.imdb.com/title/tt0099291/
# 40  https://www.imdb.com/title/tt0099310/
# 41  https://www.imdb.com/title/tt0099313/
# 42  https://www.imdb.com/title/tt0099316/
# 43  https://www.imdb.com/title/tt0099329/
# 44  https://www.imdb.com/title/tt0099342/
# 45  https://www.imdb.com/title/tt0099348/
# 46  https://www.imdb.com/title/tt0099364/
# 47  https://www.imdb.com/title/tt0099365/
# 48  https://www.imdb.com/title/tt0099368/
# 49  https://www.imdb.com/title/tt0099371/
#
#                                    title  \
# 0        The Adventures of Ford Fairlane
# 1                   After Dark, My Sweet
# 2                            Air America
# 3                                  Alice
# 4                        Almost an Angel
# 5                          The Ambulance
# 6                         American Dream
# 7     American Ninja 4: The Annihilation
# 8                         Andre's Mother
# 9                             Angel Town
# 10                       Another 48 Hrs.
# 11                         Arachnophobia
# 12                                Avalon
# 13                            Awakenings
# 14           Back to the Future Part III
# 15                         Bad Influence
# 16                         Basket Case 2
# 17                       Betsy's Wedding
# 18                        Bird on a Wire
# 19                           Blind Faith
# 20                          Bloodfist II
# 21                            Blue Steel
# 22           The Bonfire of the Vanities
# 23                  Bride of Re-Animator
# 24                               Cadence
# 25                          Cadillac Man
# 26                        Camp Cucamonga
# 27                       Captain America
# 28       Cartoon All-Stars to the Rescue
# 29                             Catchfire
# 30                            Challenger
# 31                        Checkered Flag
# 32                    Child in the Night
# 33                        Child's Play 2
# 34                             China Cry
# 35                The China Lake Murders
# 36                         China O'Brien
# 37                         Class of 1999
# 38                 Coins in the Fountain
# 39                 Come See the Paradise
# 40                        Coupe de Ville
# 41                        Crash and Burn
# 42                          Crazy People
# 43                              Cry-Baby
# 44  Daddy's Dyin' ...Who's Got the Will?
# 45                    Dances with Wolves
# 46             The Dark Side of the Moon
# 47                               Darkman
# 48                  Daughter of Darkness
# 49                       Days of Thunder
#
#                                           Directed by  \
# 0                                        Renny Harlin
# 1                                         James Foley
# 2                                  Roger Spottiswoode
# 3                                         Woody Allen
# 4                                        John Cornell
# 5                                         Larry Cohen
# 6   [Barbara Kopple, Co-directors:, Cathy Caplan, ...
# 7                                    Cedric Sundstrom
# 8                                    Deborah Reinisch
# 9                                         Eric Karson
# 10                                        Walter Hill
# 11                                     Frank Marshall
# 12                                     Barry Levinson
# 13                                     Penny Marshall
# 14                                    Robert Zemeckis
# 15                                      Curtis Hanson
# 16                                  Frank Henenlotter
# 17                                          Alan Alda
# 18                                        John Badham
# 19                                       Paul Wendkos
# 20                                    Andy Blumenthal
# 21                                    Kathryn Bigelow
# 22                                     Brian De Palma
# 23                                        Brian Yuzna
# 24                                       Martin Sheen
# 25                                    Roger Donaldson
# 26                                     Roger Duchowny
# 27                                        Albert Pyun
# 28  [Milton Gray, Marsh Lamore, Bob Shellhorn, Mik...
# 29              [Dennis Hopper, (as, Alan Smithee, )]
# 30                                         Ben Jordan
# 31                        [John Glen, Michael Levine]
# 32                                          Mike Robe
# 33                                         John Lafia
# 34                                   James F. Collier
# 35                                       Alan Metzger
# 36                                      Robert Clouse
# 37                                     Mark L. Lester
# 38                                       Tony Wharmby
# 39                                        Alan Parker
# 40                                           Joe Roth
# 41                                       Charles Band
# 42          [Tony Bill, Barry L. Young (commercials)]
# 43                                        John Waters
# 44                                          Jack Fisk
# 45                                      Kevin Costner
# 46                                       D.J. Webster
# 47                                          Sam Raimi
# 48                                      Stuart Gordon
# 49                                         Tony Scott
#
#                                           Produced by  \
# 0                          [Steve Perry, Joel Silver]
# 1                         [Ric Kidney, Robert Redlin]
# 2                                      Daniel Melnick
# 3                                     Robert Greenhut
# 4                                        John Cornell
# 5       [Larry Cohen, Moctesuma Esparza, Robert Katz]
# 6                       [Arthur Cohn, Barbara Kopple]
# 7                                  Ovidio G Assonitis
# 8                     [Sarah Green, Deborah Reinisch]
# 9                          [Ash R. Shah, Eric Karson]
# 10                 [Lawrence Gordon, Robert D. Wachs]
# 11                   [Kathleen Kennedy, Richard Vane]
# 12                     [Mark Johnson, Barry Levinson]
# 13                [Walter F. Parkes, Lawrence Lasker]
# 14                            [Neil Canton, Bob Gale]
# 15                                        Steve Tisch
# 16                                       Edgar Ievins
# 17                [Martin Bregman, Louis A. Stroller]
# 18                                          Rob Cohen
# 19                                                NaN
# 20  [New Horizons, Concorde Pictures, (, Roger Cor...
# 21  [Edward R. Pressman, Oliver Stone, Lawrence Ka...
# 22                                     Brian De Palma
# 23                                        Brian Yuzna
# 24  [Timothy Gamble, Frank Giustra, Peter E. Strauss]
# 25                   [Roger Donaldson, Charles Roven]
# 26                                                NaN
# 27  [Joseph Calamari, Menahem Golan, Tom Karnowski...
# 28                                                NaN
# 29                                         Dick Clark
# 30                                                NaN
# 31                                    James Margellos
# 32                                                NaN
# 33                                    David Kirschner
# 34                                      Don L. Parker
# 35                                                NaN
# 36                 [Fred Weintraub, Sandra Weintraub]
# 37                                     Mark L. Lester
# 38                                                NaN
# 39              [Robert F. Colesberry, Nellie Nugiel]
# 40                   [James G. Robinson, Mike Binder]
# 41                 [David DeCoteau, John Schouweiler]
# 42                    [Thomas Brand, Robert K. Weiss]
# 43                                     Rachel Talalay
# 44                    [Steve Golin, Monty Montgomery]
# 45                        [Jim Wilson, Kevin Costner]
# 46                       [Keith Walley, D.J. Webster]
# 47                                      Robert Tapert
# 48                                                NaN
# 49                   [Don Simpson, Jerry Bruckheimer]
#
#                                         Screenplay by  \
# 0          [David Arnott, James Cappe, Daniel Waters]
# 1                        [James Foley, Robert Redlin]
# 2                          [John Eskow, Richard Rush]
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10             [John Fasano, Jeb Stuart, Larry Gross]
# 11                        [Don Jakoby, Wesley Strick]
# 12                                                NaN
# 13                                    Steven Zaillian
# 14                                           Bob Gale
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                           John Gay
# 20                                                NaN
# 21                                                NaN
# 22                                  Michael Cristofer
# 23               [Rick Fry, Woody Keith, Brian Yuzna]
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                     Stephen Tolkin
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                   James F. Collier
# 35                                                NaN
# 36                                      Robert Clouse
# 37                                 C. Courtney Joyner
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                      Michael Blake
# 46                                                NaN
# 47  [Sam Raimi, Chuck Pfarrer, Ivan Raimi, Daniel ...
# 48                                                NaN
# 49                                       Robert Towne
#
#                             Story by  \
# 0        [David Arnott, James Cappe]
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                    Fred Braughton
# 11         [Don Jakoby, Al Williams]
# 12                               NaN
# 13                               NaN
# 14       [Robert Zemeckis, Bob Gale]
# 15                               NaN
# 16                               NaN
# 17                               NaN
# 18                               NaN
# 19                     Joe McGinniss
# 20                               NaN
# 21                               NaN
# 22                               NaN
# 23                               NaN
# 24                               NaN
# 25                               NaN
# 26                               NaN
# 27  [Stephen Tolkin, Lawrence Block]
# 28                               NaN
# 29                               NaN
# 30                               NaN
# 31                               NaN
# 32                               NaN
# 33                               NaN
# 34                               NaN
# 35                               NaN
# 36                  Sandra Weintraub
# 37                    Mark L. Lester
# 38                               NaN
# 39                               NaN
# 40                               NaN
# 41                               NaN
# 42                               NaN
# 43                               NaN
# 44                               NaN
# 45                               NaN
# 46                               NaN
# 47                         Sam Raimi
# 48                               NaN
# 49        [Robert Towne, Tom Cruise]
#
#                                              Based on  \
# 0                         [Characters, by Rex Weiner]
# 1   [the novel, After Dark, My Sweet, by, Jim Thom...
# 2              [Air America, by, Christopher Robbins]
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  [Characters by, Roger Spottiswoode, Walter Hil...
# 11                                                NaN
# 12                                                NaN
# 13                     [Awakenings, by, Oliver Sacks]
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                   [Blind Faith, by, Joe McGinniss]
# 20                                                NaN
# 21                                                NaN
# 22       [The Bonfire of the Vanities, by, Tom Wolfe]
# 23                  [Characters, by, H. P. Lovecraft]
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27       [Captain America, by, Joe Simon, Jack Kirby]
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                       [Characters, by Don Mancini]
# 34    [China Cry, by, Nora Lam, & Irene Burk Harrell]
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45             [Dances with Wolves, by Michael Blake]
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                              Starring  ...  \
# 0   [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...
# 1   [Jason Patric, Rachel Ward, Bruce Dern, George...  ...
# 2   [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...
# 3   [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...
# 4         [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...
# 5   [Eric Roberts, James Earl Jones, Red Buttons, ...  ...
# 6                                                 NaN  ...
# 7   [Michael Dudikoff, David Bradley, James Booth,...  ...
# 8      [Richard Thomas, Sada Thompson, Sylvia Sidney]  ...
# 9   [Olivier Gruner, Theresa Saldana, Frank Aragon...  ...
# 10  [Eddie Murphy, Nick Nolte, Brion James, Ed O'R...  ...
# 11  [Jeff Daniels, Julian Sands, Harley Jane Kozak...  ...
# 12  [Armin Mueller-Stahl, Elizabeth Perkins, Joan ...  ...
# 13  [Robert De Niro, Robin Williams, John Heard, J...  ...
# 14  [Michael J. Fox, Christopher Lloyd, Mary Steen...  ...
# 15                           [Rob Lowe, James Spader]  ...
# 16                               Kevin Van Hentenryck  ...
# 17  [Alan Alda, Joey Bishop, Madeline Kahn, Cather...  ...
# 18  [Mel Gibson, Goldie Hawn, David Carradine, Bil...  ...
# 19  [Robert Urich, Joanna Kerns, David Barry Gray,...  ...
# 20  [Don Wilson, Maurice Smith, James Warring, Tim...  ...
# 21  [Jamie Lee Curtis, Ron Silver, Clancy Brown, E...  ...
# 22  [Tom Hanks, Bruce Willis, Melanie Griffith, Mo...  ...
# 23  [Jeffrey Combs, Bruce Abbott, Fabiana Udenio, ...  ...
# 24  [Charlie Sheen, Martin Sheen, Laurence Fishbur...  ...
# 25  [Robin Williams, Tim Robbins, Pamela Reed, Fra...  ...
# 26  [John Ratzenberger, Brian Robbins, Jennifer An...  ...
# 27  [Matt Salinger, Ronny Cox, Scott Paulin, Ned B...  ...
# 28                                                NaN  ...
# 29  [Jodie Foster, Dennis Hopper, Fred Ward, Vince...  ...
# 30  [Karen Allen, Barry Bostwick, Richard Jenkins,...  ...
# 31                                                NaN  ...
# 32  [JoBeth Williams, Tom Skerritt, Elijah Wood, D...  ...
# 33  [Alex Vincent, Jenny Agutter, Gerrit Graham, C...  ...
# 34  [Julia Nickson-Soul, France Nuyen, James Shigeta]  ...
# 35         [Isaac Allan, Tom Skerritt, Michael Parks]  ...
# 36  [Cynthia Rothrock, Richard Norton, Keith Cooke...  ...
# 37  [Bradley Gregg, Traci Lind, John P. Ryan, Pam ...  ...
# 38  [Loni Anderson, Stepfanie Kramer, Shanna Reed,...  ...
# 39  [Dennis Quaid, Tamlyn Tomita, Sab Shimono, Shi...  ...
# 40  [Patrick Dempsey, Arye Gross, Daniel Stern, An...  ...
# 41    [Paul Ganus, Megan Ward, Jack McGee, Eva LaRue]  ...
# 42          [Dudley Moore, Daryl Hannah, Paul Reiser]  ...
# 43  [Johnny Depp, Amy Locane, Susan Tyrrell, Iggy ...  ...
# 44  [Beau Bridges, Beverly D'Angelo, Tess Harper, ...  ...
# 45  [Kevin Costner, Mary McDonnell, Graham Greene,...  ...
# 46  [Robert Sampson, Will Bledsoe, Joe Turkel, Cam...  ...
# 47  [Liam Neeson, Frances McDormand, Colin Friels,...  ...
# 48  [Anthony Perkins, Mia Sara, Robert Reynolds, D...  ...
# 49  [Tom Cruise, Robert Duvall, Randy Quaid, Nicol...  ...
#
#                                        Distributed by  \
# 0                                    20th Century Fox
# 1                                     Avenue Pictures
# 2                                    TriStar Pictures
# 3                                      Orion Pictures
# 4                                  Paramount Pictures
# 5                       Triumph Releasing Corporation
# 6                                      Prestige Films
# 7                                        Cannon Group
# 8                         Public Broadcasting Service
# 9                              Imperial Entertainment
# 10                                 Paramount Pictures
# 11                               Buena Vista Pictures
# 12  [TriStar Pictures, (United States), Columbia P...
# 13                                  Columbia Pictures
# 14                                 Universal Pictures
# 15                      Triumph Releasing Corporation
# 16                  Shapiro Glickenhaus Entertainment
# 17                               Buena Vista Pictures
# 18                                 Universal Pictures
# 19                                                NaN
# 20                                                NaN
# 21                                Metro-Goldwyn-Mayer
# 22                                       Warner Bros.
# 23                                  50th Street Films
# 24               [New Line Cinema, Republic Pictures]
# 25                                     Orion Pictures
# 26                                                NaN
# 27  [20/20 Vision, (UK VHS), Columbia Tristar Home...
# 28                                                NaN
# 29                                   Vestron Pictures
# 30                                                NaN
# 31                            New World International
# 32                                                NaN
# 33                                 Universal Pictures
# 34                                Penland Productions
# 35                                                NaN
# 36  [Studio / Sterling, Golden Harvest, Media Asia...
# 37                                 Lightning Pictures
# 38                                                NaN
# 39                                   20th Century Fox
# 40                                 Universal Pictures
# 41                               Paramount Home Video
# 42                                 Paramount Pictures
# 43                                 Universal Pictures
# 44                        [MGM, /, UA, Pictures Inc.]
# 45                                     Orion Pictures
# 46                                   Trimark Pictures
# 47                                 Universal Pictures
# 48                                                NaN
# 49                                 Paramount Pictures
#
#                             Country                   Language  \
# 0                     United States                    English
# 1                     United States                    English
# 2                     United States             [English, Lao]
# 3                     United States                    English
# 4                                US                    English
# 5                     United States                    English
# 6   [United States, United Kingdom]                    English
# 7          [United States, Lesotho]                    English
# 8                     United States                    English
# 9                     United States                    English
# 10                    United States                    English
# 11                    United States                    English
# 12                    United States                    English
# 13                    United States                    English
# 14                    United States                    English
# 15                    United States                    English
# 16                              NaN                    English
# 17                    United States                    English
# 18                    United States                    English
# 19                              NaN                        NaN
# 20                    United States                    English
# 21                    United States                    English
# 22                    United States                    English
# 23                    United States                    English
# 24                    United States                    English
# 25                    United States                    English
# 26                              NaN                        NaN
# 27      [Yugoslavia, United States]                    English
# 28                              NaN                        NaN
# 29                    United States                    English
# 30                              NaN                        NaN
# 31                              NaN                    English
# 32                              NaN                        NaN
# 33                    United States                    English
# 34                              USA                    English
# 35                              NaN                        NaN
# 36                              NaN                    English
# 37                    United States                    English
# 38                              NaN                        NaN
# 39                    United States                    English
# 40                    United States                    English
# 41                    United States                    English
# 42                    United States                    English
# 43                    United States                    English
# 44                    United States                    English
# 45                    United States  [English, Lakota, Pawnee]
# 46                    United States                    English
# 47                    United States                    English
# 48                              NaN                        NaN
# 49                    United States                    English
#
#                                            Written by  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                         Woody Allen
# 4                                          Paul Hogan
# 5                                         Larry Cohen
# 6                                                 NaN
# 7                                        David Geeves
# 8                                    Terrence McNally
# 9                                           S. Warren
# 10                                                NaN
# 11                                                NaN
# 12                                     Barry Levinson
# 13                                                NaN
# 14                                                NaN
# 15                                        David Koepp
# 16                                  Frank Henenlotter
# 17                                          Alan Alda
# 18                     [Louis Venosta, David Seltzer]
# 19                                                NaN
# 20                                    Catherine Cyran
# 21                   [Kathryn Bigelow, Eric Red, [1]]
# 22                                                NaN
# 23                                                NaN
# 24                                     Dennis Shryack
# 25                                       Ken Friedman
# 26  [Bennett Tramer (Story & teleplay), Rich Melco...
# 27                                                NaN
# 28                           [Duane Poole, Tom Swale]
# 29  [Rachel Kronstadt Mann, Ann Louise Bardach, Al...
# 30                                     George Englund
# 31    [Clayton Frohman, E.F. Wallengren, Jason Brett]
# 32                                    Michael Petryni
# 33                                        Don Mancini
# 34                                                NaN
# 35                                     N.D. Schreiner
# 36                                                NaN
# 37                                                NaN
# 38                                   Lindsay Harrison
# 39                                        Alan Parker
# 40                                        Mike Binder
# 41                                      J. S. Cardone
# 42                                    Mitch Markowitz
# 43                                        John Waters
# 44                                         Del Shores
# 45                                                NaN
# 46                          [Carey Hayes, Chad Hayes]
# 47                                                NaN
# 48                                      Andrew Laskos
# 49                                                NaN
#
#                                  Productioncompanies     imdb_id   Box_Office  \
# 0                                                 NaN  tt0098987   21400000.0
# 1                                                 NaN  tt0098994    2700000.0
# 2                                                 NaN  tt0099005   57718089.0
# 3                                                 NaN  tt0099012    7331647.0
# 4                                                 NaN  tt0099018    6939946.0
# 5                                                 NaN  tt0099026          NaN
# 6                                                 NaN  tt0099028          NaN
# 7                                                 NaN  tt0101326          NaN
# 8                                                 NaN  tt0099037          NaN
# 9                                                 NaN  tt0099039     855810.0
# 10                                                NaN  tt0099044  195300000.0
# 11                                                NaN  tt0099052   53200000.0
# 12                                                NaN  tt0099073   15700000.0
# 13                                                NaN  tt0099077   52100000.0
# 14                                                NaN  tt0099088  244500000.0
# 15                                                NaN  tt0099091   12626043.0
# 16                                                NaN  tt0099108          NaN
# 17                                                NaN  tt0099128   19740070.0
# 18                                                NaN  tt0099141  138697012.0
# 19                                                NaN  tt0099148          NaN
# 20                                                NaN  tt0099155    1292323.0
# 21  [Lightning Pictures, Mack-Taylor Productions, ...  tt0099160    8200000.0
# 22                                                NaN  tt0099165   15600000.0
# 23                                                NaN  tt0099180          NaN
# 24                                                NaN  tt0101531    2070871.0
# 25                                                NaN  tt0099204   27600000.0
# 26                                                NaN  tt0099212          NaN
# 27  [Marvel Entertainment Group, Jadran Film, 21st...  tt0103923      10173.0
# 28                                                NaN  tt0154129          NaN
# 29                                                NaN  tt0096875    5000000.0
# 30                                                NaN  tt0099237          NaN
# 31                                                NaN  tt0099245          NaN
# 32                                                NaN  tt0099252          NaN
# 33                                                NaN  tt0099253   35800000.0
# 34                                                NaN  tt0101578          NaN
# 35                                                NaN  tt0099259          NaN
# 36                                                NaN  tt0099260          NaN
# 37                                                NaN  tt0099277    2400000.0
# 38                                                NaN  tt0099284          NaN
# 39                                                NaN  tt0099291     947306.0
# 40                                                NaN  tt0099310     715983.0
# 41                                                NaN  tt0099313          NaN
# 42                                                NaN  tt0099316   13236513.0
# 43                                                NaN  tt0099329    8300000.0
# 44                                                NaN  tt0099342    1373728.0
# 45                                    Tig Productions  tt0099348  424200000.0
# 46                                                NaN  tt0099364          NaN
# 47                                                NaN  tt0099365   48800000.0
# 48                                                NaN  tt0099368          NaN
# 49                                                NaN  tt0099371  157900000.0
#
#         budget Release_Date Running_Time
# 0   20000000.0   1990-07-11        102.0
# 1    6000000.0   1990-05-17        114.0
# 2   35000000.0   1990-08-10        113.0
# 3   12000000.0   1990-12-25        106.0
# 4   25000000.0   1990-12-19         95.0
# 5          NaN   1990-03-22         95.0
# 6          NaN   1990-10-06        100.0
# 7          NaN   1991-03-08         99.0
# 8          NaN   1990-03-07         50.0
# 9          NaN   1990-02-23        102.0
# 10  50000000.0   1990-06-08         93.0
# 11  22000000.0   1990-07-18        110.0
# 12         NaN   1990-10-05        126.0
# 13  29000000.0   1990-12-20        121.0
# 14  40000000.0   1990-05-25        118.0
# 15   7000000.0   1990-03-09         99.0
# 16         NaN   1990-03-02         90.0
# 17         NaN   1990-06-22         94.0
# 18  20000000.0   1990-05-18        110.0
# 19         NaN          NaT        190.0
# 20         NaN   1990-10-12         85.0
# 21         NaN   1990-01-01        102.0
# 22  47000000.0   1990-12-21        126.0
# 23         NaN   1990-09-08         96.0
# 24         NaN   1990-01-01         97.0
# 25  15000000.0   1990-05-18         97.0
# 26         NaN          NaT         93.0
# 27  10000000.0   1990-12-14         97.0
# 28         NaN          NaT         32.0
# 29  10000000.0   1990-04-03         98.0
# 30         NaN          NaT          NaN
# 31         NaN   1990-01-01         95.0
# 32         NaN          NaT         98.0
# 33  13000000.0   1990-11-09         84.0
# 34         NaN   1990-11-02        101.0
# 35         NaN          NaT         97.0
# 36         NaN   1988-01-01         86.0
# 37   5200000.0   1990-05-11         99.0
# 38         NaN          NaT         97.0
# 39  17500000.0   1990-12-23        138.0
# 40         NaN   1990-03-09         99.0
# 41         NaN   1990-09-01         85.0
# 42  18000000.0   1990-04-13         91.0
# 43  12000000.0   1990-03-14         85.0
# 44   4000000.0   1990-05-04         95.0
# 45  22000000.0   1990-10-19        181.0
# 46         NaN   1990-01-01          NaN
# 47  16000000.0   1990-08-24         95.0
# 48         NaN          NaT         93.0
# 49  60000000.0   1990-06-27        108.0
#
# [50 rows x 24 columns]

# %%
# 21. Check that wiki_movies_df DataFrame columns are correct. 
wiki_movies_df.columns.to_list()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Country',
#  'Language',
#  'Written by',
#  'Productioncompanies ',
#  'imdb_id',
#  'Box_Office',
#  'budget',
#  'Release_Date',
#  'Running_Time']
